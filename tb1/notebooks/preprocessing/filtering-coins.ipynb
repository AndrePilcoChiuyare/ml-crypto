# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
# Loading the coins information
df = pd.read_csv('../../data/csv/coinmarketcap_metadata.csv')
print(df.shape)
df.head()
# Out:
# (1235, 23)
#      id                     name symbol category  \
# 0  1037  Agoras: Currency of Tau   AGRS    token
# 1  1455                    Golem    GLM    token
# 2  1637                iExec RLC    RLC    token
# 3  1732                Numeraire    NMR    token
# 4  2143                  Streamr   DATA    token
#
#                                          description                  slug  \
# 0  Agoras: Currency of Tau (AGRS) is a cryptocurr...         agoras-tokens
# 1  Golem (GLM) is a cryptocurrency launched in 20...  golem-network-tokens
# 2  iExec RLC (RLC) is a cryptocurrency and operat...                   rlc
# 3  Numeraire (NMR) is a cryptocurrency and operat...             numeraire
# 4  Streamr (DATA) is a cryptocurrency and operate...               streamr
#
#                                                 logo     subreddit  \
# 0  https://s2.coinmarketcap.com/static/img/coins/...      tauchain
# ...
