# %% [markdown]
# # Getting stable coins from Defillama

# %% [markdown]
# ## Libraries

# %%
import requests
import json
import csv
import os

# %%
# Defining API endpoint
url = 'https://stablecoins.llama.fi/stablecoins?includePrices=falses'

# Request headers
headers = {
    'Accepts': 'application/json'
}

# Do the GET request
response = requests.get(url, headers=headers)

# %%
# Defining json saving path
json_path = '../../data/json/stable-coins.json'

# Defining csv saving path
csv_path = '../../data/csv/stable-coins.csv'

# Verify if the request was susccessfull
if response.status_code == 200:
    data = response.json()
    print('Succesfull request :)')
    print('---------------------')
    print(data)
    print('---------------------')

    # Serializing JSON
    json_data = json.dumps(data, indent=4)

    # Saving the stable coins response in a json file
    with open(json_path, 'w') as outfile:
        outfile.write(json_data)
        print('JSON successfully saved')
        print('-----------------------')

    # Get stable coins list
    coins = data.get('peggedAssets', [])

    # check if it's a list  and it's not empty
    if coins and isinstance(coins, list):
        with open(csv_path, 'w', newline='', encoding='utf-8') as outfile:
            # Defining the field names to include
            fieldnames = ['name', 'symbol', 'gecko_id']

            # Create the CSV writer
            writer = csv.DictWriter(outfile, fieldnames=fieldnames)

            # Write headers
            writer.writeheader()

            # Write the data rows
            for coin in coins:
                if isinstance(coin, dict):
                    # Ensuring that every coin has the needed keys
                    row = {field: coin.get(field, '') for field in fieldnames}
                    writer.writerow(row)
                else:
                    print(f'Warning: Expected dict but got {type(coin)}')
        print(f'CSV successfully saved at {csv_path}')
else:
    print(f'Error: {response.status_code}')
    print(response.text)
# Out:
# Succesfull request :)
# ---------------------
# {'peggedAssets': [{'id': '1', 'name': 'Tether', 'symbol': 'USDT', 'gecko_id': 'tether', 'pegType': 'peggedUSD', 'priceSource': 'defillama', 'pegMechanism': 'fiat-backed', 'circulating': {'peggedUSD': 118853251349.1602}, 'circulatingPrevDay': {'peggedUSD': 118812287089.75371}, 'circulatingPrevWeek': {'peggedUSD': 118420988938.3841}, 'circulatingPrevMonth': {'peggedUSD': 116887299260.33615}, 'chainCirculating': {'Optimism': {'current': {'peggedUSD': 1167091061.603716}, 'circulatingPrevDay': {'peggedUSD': 1167023661.109423}, 'circulatingPrevWeek': {'peggedUSD': 1153976259.068159}, 'circulatingPrevMonth': {'peggedUSD': 1106057733.436055}}, 'Statemine': {'current': {'peggedUSD': 239995}, 'circulatingPrevDay': {'peggedUSD': 239995}, 'circulatingPrevWeek': {'peggedUSD': 239995}, 'circulatingPrevMonth': {'peggedUSD': 239995}}, 'Manta': {'current': {'peggedUSD': 9373874.146389}, 'circulatingPrevDay': {'peggedUSD': 9390209.274389}, 'circulatingPrevWeek': {'peggedUSD': 6692649.904742}, 'circulatingPrevMonth': {'peggedUSD': 6970908.39785}}, 'Harmony': {'current': {'peggedUSD': 0}, 'circulatingPrevDay': {'peggedUSD': 0}, 'circulatingPrevWeek': {'peggedUSD': 0}, 'circulatingPrevMonth': {'peggedUSD': 0}}, 'ThunderCore': {'current': {'peggedUSD': 679856.396994}, 'circulatingPrevDay': {'peggedUSD': 679856.396994}, 'circulatingPrevWeek': {'peggedUSD': 679727.266994}, 'circulatingPrevMonth': {'peggedUSD': 683418.25693}}, 'BSC': {'current': {'peggedUSD': 3982728481.188213}, 'circulatingPrevDay': {'peggedUSD': 3982628084.82472}, 'circulatingPrevWeek': {'peggedUSD': 3982550913.991758}, 'circulatingPrevMonth': {'peggedUSD': 3984907435.3871756}}, 'Dogechain': {'current': {'peggedUSD': 33989.936475}, 'circulatingPrevDay': {'peggedUSD': 33989.936475}, 'circulatingPrevWeek': {'peggedUSD': 33989.936475}, 'circulatingPrevMonth': {'peggedUSD': 33989.936475}}, 'Astar': {'current': {'peggedUSD': 737298.781194}, 'circulatingPrevDay': {'peggedUSD': 737298.781194}, 'circulatingPrevWeek': {'peggedUSD': 735644.374827}, 'circulatingPrevMonth': {'peggedUSD': 724633.1939300001}}, 'Oasis': {'current': {'peggedUSD': 412498.97440572}, 'circulatingPrevDay': {'peggedUSD': 412498.97440571996}, 'circulatingPrevWeek': {'peggedUSD': 412498.97440572}, 'circulatingPrevMonth': {'peggedUSD': 450130.71948772}}, 'Heco': {'current': {'peggedUSD': 41773125.49422048}, 'circulatingPrevDay': {'peggedUSD': 41773125.49422048}, 'circulatingPrevWeek': {'peggedUSD': 41773125.49422048}, 'circulatingPrevMonth': {'peggedUSD': 41773125.49422048}}, 'Shiden': {'current': {'peggedUSD': 9859.073146}, 'circulatingPrevDay': {'peggedUSD': 9859.073146}, 'circulatingPrevWeek': {'peggedUSD': 9859.073146}, 'circulatingPrevMonth': {'peggedUSD': 9859.073146}}, 'Avalanche': {'current': {'peggedUSD': 1483975144.697632}, 'circulatingPrevDay': {'peggedUSD': 1449006941.791257}, 'circulatingPrevWeek': {'peggedUSD': 1384113461.8006878}, 'circulatingPrevMonth': {'peggedUSD': 1364181523.2489796}}, 'StarkNet': {'current': {'peggedUSD': 21334423.212377}, 'circulatingPrevDay': {'peggedUSD': 22195035.832377}, 'circulatingPrevWeek': {'peggedUSD': 28202557.426162}, 'circulatingPrevMonth': {'peggedUSD': 23385962.103229}}, 'Telos': {'current': {'peggedUSD': 203186.058623}, 'circulatingPrevDay': {'peggedUSD': 203186.058623}, 'circulatingPrevWeek': {'peggedUSD': 203186.058623}, 'circulatingPrevMonth': {'peggedUSD': 203186.058623}}, 'Arbitrum': {'current': {'peggedUSD': 2899398707.992903}, 'circulatingPrevDay': {'peggedUSD': 2887942149.305152}, 'circulatingPrevWeek': {'peggedUSD': 2849927669.684132}, 'circulatingPrevMonth': {'peggedUSD': 2736229660.817314}}, 'Tron': {'current': {'peggedUSD': 58737684393.07857}, 'circulatingPrevDay': {'peggedUSD': 58842233991.3703}, 'circulatingPrevWeek': {'peggedUSD': 58602562794.58134}, 'circulatingPrevMonth': {'peggedUSD': 58553830308.822235}}, 'Stacks': {'current': {'peggedUSD': 1394103.9972077475}, 'circulatingPrevDay': {'peggedUSD': 1441885.027817755}, 'circulatingPrevWeek': {'peggedUSD': ...
# ---------------------
# JSON successfully saved
# -----------------------
# CSV successfully saved at ../../data/csv/stable-coins.csv
